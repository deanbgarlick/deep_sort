# %%
import base64
import datetime
import pickle

import cv2
import numpy as np

from kafka import KafkaConsumer, KafkaProducer
from PIL import Image


def from_base64(buf):
    buf_decode = base64.b64decode(buf)
    buf_arr = np.fromstring(buf_decode, dtype=np.uint8)
    return cv2.imdecode(buf_arr, cv2.IMREAD_UNCHANGED)


topic_in = "object-detections"


def main():


    consumer = KafkaConsumer(
        topic_in,
        bootstrap_servers=['kafka1:19091']
    )
    

    image_id = -1

    for msg in consumer:
        print(msg)

# %%
main()
# Out:
# ConsumerRecord(topic='object-detections', partition=0, offset=26, timestamp=1609407780855, timestamp_type=0, key=None, value=b'...', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=355352, serialized_header_size=-1)
# ConsumerRecord(topic='object-detections', partition=0, offset=27, timestamp=1609407784644, timestamp_type=0, key=None, value=b'...', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=358612, serialized_header_size=-1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-6-4f85edf80aa6> in main()
#      30     image_id = -1
#      31
# ---> 32     for msg in consumer:
#      33         print(msg)
#
# /usr/local/lib/python3.6/dist-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# /usr/local/lib/python3.6/dist-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# /usr/local/lib/python3.6/dist-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# /usr/local/lib/python3.6/dist-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# /usr/local/lib/python3.6/dist-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# /usr/local/lib/python3.6/dist-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# /usr/local/lib/python3.6/dist-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# /usr/lib/python3.6/selectors.py in select(self, timeout)
#     443             ready = []
#     444             try:
# --> 445                 fd_event_list = self._epoll.poll(timeout, max_ev)
#     446             except InterruptedError:
#     447                 return ready
#
# KeyboardInterrupt:
